# %% [markdown]
# # 🧠 Manage Your Local Jupyter Server from a Notebook
#
# This notebook provides full control over your local Jupyter server directly from within a Jupyter/Colab/VS Code notebook. You can:
#
# - ✅ Start, stop, restart the server
# - 🔍 Check status
# - 🌐 Open the local server UI
# - 🛠️ Automatically install required and optional packages using a shell script
#
# This is ideal when:
# - You're working across Colab and local environments
# - You want full reproducibility for AI/ML workflows
# - You need an interactive, scriptable environment setup process
#
# ---
#
# 📂 The shell script it controls is located in the same project directory: `jupyter_server.sh`.
#
# 🚨 All critical actions prompt for confirmation unless you override with CLI flags like `--auto-all`.
#
# ---

# %% [markdown]
# ## Server management helper markdown
# ## 🛠️ Server Management Helper Function
#
# This helper function, `run_server_command(...)`, allows this notebook to call the `jupyter_server.sh` shell script from Python.
#
# Each call:
# - Displays which command is being run (`start`, `stop`, `restart`, `status`)
# - Prompts you for confirmation before executing (safe by default)
# - Shows success/failure messages inline
#
# The script itself supports optional automation flags such as:
# - `--auto-all`: install everything
# - `--auto-none`: skip all optional installs
# - `--auto=gpu,rag`: selective install
# - `--prompt`: interactive prompt during setup

# %%
# 🛠️ Server Management Helpers (Updated)
# Out:
# ✅ Found venv Python executable: c:\Users\chris\Documents\jupyter_server\venv\Scripts\python.exe
# ✅ Server management helpers loaded successfully.
# ℹ️ Will use Venv Python Executable: c:\Users\chris\Documents\jupyter_server\venv\Scripts\python.exe

# %% [markdown]
# ### ▶️ Start Jupyter Notebook Server
#
# This cell starts the local Jupyter Notebook server in a background process and records its PID.
#
# **What it does:**
# - Activates the virtual environment
# - Launches Jupyter Notebook on `localhost:8888`
# - Writes the server's process ID (PID) to a `.jupyter_server.pid` file
#
# You only need to run this if:
# - The server isn't already running
# - You want to connect locally or from Colab to your machine
#
# > 💡 To verify it started, check the terminal output and access [http://localhost:8888](http://localhost:8888) in your browser.
#
# ---

# %% [markdown]
# ## 🚀 Start Local Jupyter Server
#
# This cell will start the local Jupyter server using the `jupyter_server.sh` script.
#
# You’ll be asked to confirm before proceeding. If accepted, the server will:
# - Start in the background
# - Become accessible via [http://localhost:8888](http://localhost:8888/)
# - Be visible from Colab (via local runtime) or your browser
#
# To bypass confirmation, you could call:
# ```python
# run_server_command("start", auto_confirm=True)

# %%
# 🚀 Start Local Jupyter Server

confirm = input("⚡ Are you sure you want to START the Jupyter server? (yes/no): ")
if confirm.lower() == "yes":
    run_server_command("start") # Calls 'start' command; script finds python internally
else:
    print("⛔ Start aborted by user.")
# Out:
# ℹ️ Running command list: ['bash', 'jupyter_server.sh', 'start', 'c:\\Users\\chris\\Documents\\jupyter_server\\venv\\Scripts\\python.exe']
# --- stdout ---
# Using venv Python: /mnt/c/Users/chris/Documents/jupyter_server/venv/Scripts/python.exe
# Starting Jupyter Notebook server using /mnt/c/Users/chris/Documents/jupyter_server/venv/Scripts/python.exe ...
# Starting Jupyter server in the background... Logging to /mnt/c/Users/chris/Documents/jupyter_server/jupyter_server.log
#  Jupyter server started. PID 373
# --------------

# %%
import subprocess
import os
import sys
import shlex  # Import shlex for better logging if needed

# --- Define PROJECT_DIR, VENV_DIR, SCRIPT_PATH, VENV_PYTHON_EXE earlier in your notebook ---
# Ensure these variables are defined before this function is called.
# Example (adapt paths as needed):
# PROJECT_DIR = os.path.abspath('.') # Or specific path
# VENV_DIR = os.path.join(PROJECT_DIR, 'venv')
# SCRIPT_PATH = os.path.abspath(os.path.join(PROJECT_DIR, 'jupyter_server.sh'))
# VENV_PYTHON_EXE = os.path.join(VENV_DIR, 'Scripts', 'python.exe') if sys.platform == 'win32' else os.path.join(VENV_DIR, 'bin', 'python')
# Note: This path is now primarily used by setup_environment within the script, not passed directly to start/restart.
# ------------------------------------------------------------------------------------

def run_server_command(command, optional_args=[]):
    """
    Runs a command via the jupyter_server.sh script.

    Args:
        command (str): The main command (e.g., 'setup', 'start', 'stop').
        optional_args (list, optional): A list of optional string arguments/flags
                                       (e.g., ['--auto-none']). Defaults to [].
    """
    if not os.path.exists(SCRIPT_PATH):
        print(f"❌ ERROR: Script not found at '{SCRIPT_PATH}'. Cannot proceed.")
        return

    # Base command list
    cmd_list = ["bash", "jupyter_server.sh", command] # Use only the script filename; cwd is set, so bash finds it.

    # Add specific required positional arguments based on command
    if command in ["start", "restart"]:
        if not VENV_PYTHON_EXE or not os.path.exists(VENV_PYTHON_EXE):
            print(f"❌ ERROR: Cannot run '{command}' without a valid venv Python executable path.")
            print(f"   (Expected at: '{VENV_PYTHON_EXE}')")
            return
        cmd_list.append(VENV_PYTHON_EXE)
    elif command == "setup":
        if not PROJECT_DIR or not os.path.isdir(PROJECT_DIR):
            print(f"❌ ERROR: Cannot run 'setup' without a valid PROJECT_DIR.")
            print(f"   (PROJECT_DIR: '{PROJECT_DIR}')")
            return
        # Convert path for bash/pip compatibility
        project_dir_for_bash = PROJECT_DIR.replace('\\', '/') # Convert project dir path to forward slashes for bash/pip compatibility when running setup
        cmd_list.append(project_dir_for_bash)  # Required arg for setup

    # Append all optional arguments/flags passed in the list
    cmd_list.extend(optional_args)

    try:
        # Log the command list clearly
        print(f"ℹ️ Running command list: {cmd_list}")
        # Example using shlex.join for a potentially more readable log (optional):
        # print(f"ℹ️ Running command: bash {shlex.quote(SCRIPT_PATH)} {' '.join(shlex.quote(arg) for arg in cmd_list[2:])}")

        result = subprocess.run(cmd_list,  # Pass the list directly
                                capture_output=True, text=True, cwd=PROJECT_DIR,
                                encoding='utf-8', errors='replace', check=False)  # check=False for manual check

        print("--- stdout ---")
        if result.stdout:
            print(result.stdout.strip())
        print("--------------")

        if result.returncode != 0:
            print("--- stderr ---")
            if result.stderr:
                print(result.stderr.strip())
            print("--------------")
            print(f"❌ Command '{command}' with args {optional_args} failed with exit code {result.returncode}")
        # Optional: Add a success message if needed
        # else:
        #    print(f"✅ Command '{command}' executed successfully.")

    except FileNotFoundError:
        print(f"❌ ERROR: Failed to execute command. Is 'bash' installed and in your system's PATH?")
        print(f"   Command list was: {cmd_list}")
    except Exception as e:
        print(f"❌ Exception during subprocess execution: {e}")
        print(f"   Command list was: {cmd_list}")

# --- End of function definition ---

# %% [markdown]
# ## 🔄 Restart Local Jupyter Server
#
# This cell stops and then starts the Jupyter server — useful after:
# - Installing new packages
# - Making config changes
# - Clearing memory or hung processes
#
# You’ll get a confirmation prompt before restart.
#
# To run without prompt:
# ```python
# run_server_command("restart", auto_confirm=True)

# %%
# 🔄 Restart Local Jupyter Server

confirm = input("🔄 Are you sure you want to RESTART the Jupyter server? (yes/no): ")
if confirm.lower() == "yes":
    run_server_command("restart")
else:
    print("⛔ Restart aborted by user.")
# Out:
# ℹ️ Running command list: ['bash', 'jupyter_server.sh', 'restart', 'c:\\Users\\chris\\Documents\\jupyter_server\\venv\\Scripts\\python.exe']
# --- stdout ---
# Restarting Jupyter server...
# Process 303 not found. Removing stale PID file.
# Starting Jupyter Notebook server using c:UserschrisDocumentsjupyter_servervenvScriptspython.exe ...
#  Jupyter server started. PID 351
# --------------

# %% [markdown]
# ## 🛑 Stop Local Jupyter Server
#
# Use this cell to stop the currently running Jupyter server process cleanly.
#
# ✅ This helps prevent orphaned processes and port binding issues.
#
# Like before:
# - You’ll be prompted to confirm.
# - To bypass confirmation, use:
# ```python
# run_server_command("stop", auto_confirm=True)

# %%
# 🛑 Stop Local Jupyter Server

confirm = input("⚠️ Are you sure you want to STOP the Jupyter server? (yes/no): ")
if confirm.lower() == "yes":
    run_server_command("stop")
else:
    print("⛔ Stop aborted by user.")
# Out:
# ℹ️ Running command list: ['bash', 'jupyter_server.sh', 'stop']
# --- stdout ---
# Process 316 not found. Removing stale PID file.
# --------------

# %% [markdown]
# ## 🔍 Check Jupyter Server Status
#
# This cell lets you check if the Jupyter server is currently running.
#
# It’s useful for:
# - Verifying whether the server is alive after setup
# - Debugging failed connections to `localhost:8888`
# - Seeing the PID (process ID) for advanced process control
#
# To skip the prompt and run directly:
# ```python
# run_server_command("status", auto_confirm=True)

# %%
# 🔍 Check Jupyter Server Status

run_server_command("status")
# Out:
# ✅ Jupyter server is running (PID 7992).

# %% [markdown]
# ## 🌐 Open Local Jupyter Server Link
#
# This cell provides a clickable link to open your local Jupyter server at:
#
# 👉 [http://localhost:8888/](http://localhost:8888/)
#
# You should:
# - ✅ Make sure the server is running (`start` or `restart` it if not)
# - ✅ Use this link in Colab by going to `Runtime → Connect to local runtime`
#
# 💡 If the link fails:
# - Use the **status check** to confirm it’s running
# - Check for port conflicts or firewall issues

# %%
# 🌐 Open Local Jupyter Server Link

from IPython.display import display, HTML

display(HTML("<a href='http://localhost:8888/' target='_blank' style='font-size:20px;'>🚀 Open Local Jupyter Server</a>"))
print("📢 If server is running, click the link above. If it refuses connection, start the server first.")
print("🔄 In Colab: Runtime → Disconnect → Connect to local runtime → Enter http://localhost:8888/")
# !jupyter server list
# Out:
# <a href='http://localhost:8888/' target='_blank' style='font-size:20px;'>🚀 Open Local Jupyter Server</a>
# 📢 If server is running, click the link above. If it refuses connection, start the server first.
# 🔄 In Colab: Runtime → Disconnect → Connect to local runtime → Enter http://localhost:8888/
# Currently running servers:
# http://localhost:8888/?token=009df34aa126640eff1fdcb0ef8da872532e730549d44006 :: /Users/holtharvey/Documents/GitHub/jupyter_server

# %%
import subprocess
import re

# Fetch running server info
server_output = subprocess.getoutput("jupyter server list")

# Search for token pattern
match_token = re.search(r"token=([\w\d]+)", server_output)
match_url = re.search(r"(http://localhost:\d+/\?token=\w+)", server_output)
if match_token and match_url:
    token = match_token.group(1)
    url = match_url.group(1)
    print(f"🌐 URL: {url}")
    print(f"🔐 Token: {token}")
else:
    print("❌ No url or token found. Is the Jupyter server running?")
# Out:
# 🔐 URL: http://localhost:8888/?token=009df34aa126640eff1fdcb0ef8da872532e730549d44006
# 🔐 Token: 009df34aa126640eff1fdcb0ef8da872532e730549d44006

# %% [markdown]
# ## 🔐 Make Shell Script Executable (Optional in Notebook)
# If you plan to run jupyter_server.sh from the terminal, it needs executable permission.
#
# This cell runs:
# ```bash
# chmod +x jupyter_server.sh

# %%
import os

# 📌 Make Shell Script Executable
if os.path.isfile("jupyter_server.sh"):
    # !chmod +x jupyter_server.sh
    print("✅ Shell script is now executable.")
else:
    print("❌ jupyter_server.sh not found in current directory.")
# Out:
# ✅ Shell script is now executable.

# %% [markdown]
# ## ⚙️ Setup Environment with Optional Interactive Install
#
# This runs the full setup routine using the `jupyter_server.sh` script with the `--prompt` flag.
#
# You’ll be:
# - 🧱 Creating a new Python virtual environment (if not already created)
# - 📦 Installing all **base/core** packages listed in `requirements-base.txt`
# - ❓ Prompted interactively to choose which **optional modules** (e.g. GPU, RAG, Agents, LLM training) to install
#
# This mode is best when:
# - You're doing a **first-time setup**
# - You want **control** over what gets installed
# - You’re testing or comparing optional environments
#
# If you want full automation instead, use:
# ```bash
# !./jupyter_server.sh setup --auto-all

# %% [markdown]
# ## 🤖 Install Optional Packages Directly from Notebook (Full Auto Mode)
#
# This cell runs the setup script in **non-interactive mode**, installing:
#
# - ✅ Core base packages (`requirements-base.txt`)
# - ✅ All optional groups:
#   - GPU support
#   - Retrieval-Augmented Generation (RAG)
#   - Agentic workflows
#   - LLM training libraries
#
# This mode is ideal when:
# - You want to fully automate provisioning
# - You're setting up new environments on multiple machines
# - You trust the entire optional stack to be useful
#
# ---
#
# ### ⚙️ Script Parameters Overview
#
# You can customize behavior using the following flags:
#
# | Flag | Behavior |
# |------|----------|
# | `--auto-all` | Installs **all optional packages** with no prompts |
# | `--auto-none` | Installs **only base packages**, skips all optional installs |
# | `--prompt` | Interactive prompts for each optional group |
# | `--auto=gpu,rag` | Installs **only** the listed optional groups (comma-separated list) |
#
# ---
#
# ⚠️ This full auto mode may take **significantly longer** and use **more memory**.
# If you want selective control instead, run:
#
# ```bash
# !./jupyter_server.sh setup --prompt

# %%
import os
import sys
import subprocess

# --- Start: Add venv creation logic ---
# Assuming VENV_DIR is defined globally in the notebook, e.g.,
# VENV_DIR = os.path.join(PROJECT_DIR, "venv")

if not os.path.exists(VENV_DIR):
    print(f"ℹ️ Virtual environment not found at {VENV_DIR}. Creating it now...")
    try:
        # Use the current Python interpreter to create the venv
        process_result = subprocess.run([sys.executable, "-m", "venv", VENV_DIR],
                                        capture_output=True, text=True, check=True, cwd=PROJECT_DIR)
        print("✅ Virtual environment created successfully.")
        # print(process_result.stdout) # Optional: view output
    except subprocess.CalledProcessError as e:
        print(f"❌ ERROR: Failed to create virtual environment using '{sys.executable}'.")
        print(f"   Exit Code: {e.returncode}")
        print(f"   Stderr: {e.stderr}")
        # Stop execution in this cell if venv creation fails
        raise Exception("Venv creation failed, cannot proceed with setup.")
    except FileNotFoundError:
         print(f"❌ ERROR: Could not find Python executable '{sys.executable}' to create venv.")
         raise Exception("Venv creation failed, cannot proceed with setup.")
else:
    print(f"✅ Virtual environment already exists at {VENV_DIR}.")
# --- End: Add venv creation logic ---

# Now, proceed with calling the script to install packages
print("🚀 Running script to install packages into venv...")
run_server_command("setup", ["--auto-none"]) # Calls 'setup' command, passing project dir and optional flags
print("✅ Script execution finished.")
# Out:
# ✅ Virtual environment already exists at c:\Users\chris\Documents\jupyter_server\venv.
# 🚀 Running script to install packages into venv...
# ℹ️ Running command list: ['bash', 'jupyter_server.sh', 'setup', 'c:/Users/chris/Documents/jupyter_server', '--auto-none']
# --- stdout ---
# Assuming virtual environment directory already exists at /mnt/c/Users/chris/Documents/jupyter_server/venv (Bash path)
#  Using Windows Project Directory for requirements: c:/Users/chris/Documents/jupyter_server
#  Using venv Python for pip: /mnt/c/Users/chris/Documents/jupyter_server/venv/Scripts/python.exe
#  Using base requirements path for pip: c:/Users/chris/Documents/jupyter_server/requirements-base.txt
# Installing core requirements (base)...
#   Running: "/mnt/c/Users/chris/Documents/jupyter_server/venv/Scripts/python.exe" -m pip install --upgrade pip
# Requirement already satisfied: pip in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (25.1)
#   Running: "/mnt/c/Users/chris/Documents/jupyter_server/venv/Scripts/python.exe" -m pip install -r "c:/Users/chris/Documents/jupyter_server/requirements-base.txt"
# Requirement already satisfied: ipython in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 1)) (8.36.0)
# Requirement already satisfied: jupyter in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 2)) (1.1.1)
# Requirement already satisfied: jupyterlab in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (4.4.1)
# Requirement already satisfied: notebook in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 4)) (7.4.1)
# Requirement already satisfied: jupyter_http_over_ws in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 5)) (0.0.8)
# Requirement already satisfied: ipykernel in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 6)) (6.29.5)
# Requirement already satisfied: ipywidgets in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 7)) (8.1.6)
# Requirement already satisfied: nbconvert in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 8)) (7.16.6)
# Requirement already satisfied: numpy in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 9)) (2.2.5)
# Requirement already satisfied: pandas in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 10)) (2.2.3)
# Requirement already satisfied: scipy in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 11)) (1.15.2)
# Requirement already satisfied: pyarrow in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 12)) (19.0.1)
# Requirement already satisfied: fastparquet in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 13)) (2024.11.0)
# Requirement already satisfied: openpyxl in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 14)) (3.1.5)
# Requirement already satisfied: xlrd in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 15)) (2.0.1)
# Requirement already satisfied: matplotlib in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 16)) (3.10.1)
# Requirement already satisfied: seaborn in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 17)) (0.13.2)
# Requirement already satisfied: plotly in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 18)) (6.0.1)
# Requirement already satisfied: bokeh in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 19)) (3.7.2)
# Requirement already satisfied: altair in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 20)) (5.5.0)
# Requirement already satisfied: holoviews in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 21)) (1.20.2)
# Requirement already satisfied: hvplot in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 22)) (0.11.3)
# Requirement already satisfied: networkx in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 23)) (3.4.2)
# Requirement already satisfied: pyvis in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 24)) (0.3.2)
# Requirement already satisfied: scikit-learn in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 25)) (1.6.1)
# Requirement already satisfied: xgboost in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 26)) (3.0.0)
# Requirement already satisfied: lightgbm in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 27)) (4.6.0)
# Requirement already satisfied: catboost in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 28)) (1.2.8)
# Requirement already satisfied: optuna in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 29)) (4.3.0)
# Requirement already satisfied: hyperopt in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 30)) (0.2.7)
# Requirement already satisfied: mlflow in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (2.22.0)
# Requirement already satisfied: requests in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 32)) (2.32.3)
# Requirement already satisfied: urllib3 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 33)) (2.4.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 34)) (4.13.4)
# Requirement already satisfied: lxml in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 35)) (5.4.0)
# Requirement already satisfied: fastapi in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 36)) (0.115.12)
# Requirement already satisfied: flask in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 37)) (3.1.0)
# Requirement already satisfied: uvicorn in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 38)) (0.34.2)
# Requirement already satisfied: pydantic in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 39)) (2.11.4)
# Requirement already satisfied: loguru in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 40)) (0.7.3)
# Requirement already satisfied: rich in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 41)) (14.0.0)
# Requirement already satisfied: python-dotenv in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 42)) (1.1.0)
# Requirement already satisfied: cryptography in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 43)) (44.0.2)
# Requirement already satisfied: pyjwt in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 44)) (2.10.1)
# Requirement already satisfied: boto3 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 45)) (1.38.6)
# Requirement already satisfied: pymysql in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 46)) (1.1.1)
# Requirement already satisfied: psycopg2-binary in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 47)) (2.9.10)
# Requirement already satisfied: pymongo in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 48)) (4.12.1)
# Requirement already satisfied: redis in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 49)) (6.0.0)
# Requirement already satisfied: google-cloud-storage in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 50)) (3.1.0)
# Requirement already satisfied: google-cloud-firestore in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 51)) (2.20.2)
# Requirement already satisfied: pytest in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 52)) (8.3.5)
# Requirement already satisfied: pytest-cov in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 53)) (6.1.1)
# Requirement already satisfied: hypothesis in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 54)) (6.131.9)
# Requirement already satisfied: nbval in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 55)) (0.11.0)
# Requirement already satisfied: watermark in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 56)) (2.5.0)
# Requirement already satisfied: psutil in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from -r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 57)) (7.0.0)
# Requirement already satisfied: colorama in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from ipython->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 1)) (0.4.6)
# Requirement already satisfied: decorator in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from ipython->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 1)) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from ipython->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 1)) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from ipython->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 1)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from ipython->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 1)) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from ipython->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 1)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from ipython->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 1)) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from ipython->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 1)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from ipython->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 1)) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from ipython->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 1)) (4.13.2)
# Requirement already satisfied: wcwidth in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 1)) (0.2.13)
# Requirement already satisfied: jupyter-console in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 2)) (6.6.3)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (3.1.6)
# Requirement already satisfied: jupyter-core in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (0.2.4)
# Requirement already satisfied: packaging in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (24.2)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (65.5.0)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (2.2.1)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (6.4.2)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (2.0.15)
# Requirement already satisfied: pyzmq>=24 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (26.4.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (4.23.0)
# Requirement already satisfied: six>=1.6.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter_http_over_ws->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 5)) (1.17.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from ipykernel->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 6)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from ipykernel->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 6)) (1.8.14)
# Requirement already satisfied: nest-asyncio in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from ipykernel->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 6)) (1.6.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from ipywidgets->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 7)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from ipywidgets->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 7)) (3.0.14)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 8)) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from nbconvert->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 8)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from nbconvert->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 8)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from nbconvert->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 8)) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from nbconvert->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 8)) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from nbconvert->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 8)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from nbconvert->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 8)) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from pandas->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from pandas->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 10)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from pandas->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 10)) (2025.2)
# Requirement already satisfied: cramjam>=2.3 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from fastparquet->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 13)) (2.10.0)
# Requirement already satisfied: fsspec in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from fastparquet->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 13)) (2025.3.2)
# Requirement already satisfied: et-xmlfile in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from openpyxl->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 14)) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from matplotlib->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 16)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from matplotlib->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 16)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from matplotlib->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 16)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from matplotlib->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 16)) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from matplotlib->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 16)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from matplotlib->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 16)) (3.2.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from plotly->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 18)) (1.37.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from bokeh->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 19)) (6.0.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from bokeh->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 19)) (2025.4.0)
# Requirement already satisfied: colorcet in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from holoviews->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 21)) (3.1.0)
# Requirement already satisfied: panel>=1.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from holoviews->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 21)) (1.6.3)
# Requirement already satisfied: param<3.0,>=2.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from holoviews->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 21)) (2.2.0)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from holoviews->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 21)) (3.0.4)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from pyvis->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 24)) (4.0.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from scikit-learn->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 25)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from scikit-learn->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 25)) (3.6.0)
# Requirement already satisfied: graphviz in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from catboost->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 28)) (0.20.3)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from optuna->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 29)) (1.15.2)
# Requirement already satisfied: colorlog in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from optuna->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 29)) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from optuna->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 29)) (2.0.40)
# Requirement already satisfied: tqdm in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from optuna->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 29)) (4.67.1)
# Requirement already satisfied: future in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from hyperopt->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 30)) (1.0.0)
# Requirement already satisfied: cloudpickle in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from hyperopt->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 30)) (3.1.1)
# Requirement already satisfied: py4j in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from hyperopt->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 30)) (0.10.9.9)
# Requirement already satisfied: mlflow-skinny==2.22.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (2.22.0)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (3.4.3)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (3.8)
# Requirement already satisfied: waitress<4 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (3.0.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (8.1.8)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (0.51.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (8.6.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (1.32.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (1.32.1)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (5.29.4)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (0.5.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from requests->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 32)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from requests->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 32)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from requests->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 32)) (2025.4.26)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from fastapi->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 36)) (0.46.2)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from flask->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 37)) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from flask->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 37)) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from flask->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 37)) (1.9.0)
# Requirement already satisfied: h11>=0.8 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from uvicorn->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 38)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from pydantic->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 39)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from pydantic->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 39)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from pydantic->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 39)) (0.4.0)
# Requirement already satisfied: Mako in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from alembic>=1.5.0->optuna->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 29)) (1.3.10)
# Requirement already satisfied: google-auth~=2.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (2.39.0)
# Requirement already satisfied: pywin32>=304 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from docker<8,>=4.0.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (310)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from graphene<4->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from graphene<4->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (3.2.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (3.21.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (0.53b1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (0.6.1)
# Requirement already satisfied: greenlet>=1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from sqlalchemy>=1.4.2->optuna->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 29)) (3.2.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (1.3.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from beautifulsoup4->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 34)) (2.7)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from loguru->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 40)) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from rich->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 41)) (3.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from cryptography->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 43)) (1.17.1)
# Requirement already satisfied: botocore<1.39.0,>=1.38.6 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from boto3->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 45)) (1.38.6)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from boto3->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 45)) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from boto3->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 45)) (0.12.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from pymongo->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 48)) (2.7.0)
# Requirement already satisfied: async-timeout>=4.0.3 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from redis->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 49)) (5.0.1)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from google-cloud-storage->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 50)) (2.25.0rc0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.4.2 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from google-cloud-storage->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 50)) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from google-cloud-storage->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 50)) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from google-cloud-storage->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 50)) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 50)) (1.70.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 50)) (1.26.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-firestore->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 51)) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-firestore->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 51)) (1.71.0)
# Requirement already satisfied: iniconfig in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from pytest->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 52)) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from pytest->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 52)) (1.5.0)
# Requirement already satisfied: coverage>=7.5 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from coverage[toml]>=7.5->pytest-cov->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 53)) (7.8.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from hypothesis->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 54)) (25.3.0)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from hypothesis->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 54)) (2.4.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (21.2.0)
# Requirement already satisfied: webencodings in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 8)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 8)) (1.4.0)
# Requirement already satisfied: pycparser in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from cffi>=1.12->cryptography->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 43)) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 31)) (1.17.2)
# Requirement already satisfied: httpcore==1.* in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from httpx>=0.25.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (1.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jedi>=0.16->ipython->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 1)) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-core->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (4.3.7)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (3.3.0)
# Requirement already satisfied: rfc3339-validator in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (24.11.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 41)) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (2.21.1)
# Requirement already satisfied: linkify-it-py in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from panel>=1.0->holoviews->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 21)) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from panel>=1.0->holoviews->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 21)) (0.4.2)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 3)) (2.9.0.20241206)
# Requirement already satisfied: uc-micro-py in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from linkify-it-py->panel>=1.0->holoviews->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 21)) (1.0.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from stack_data->ipython->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 1)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from stack_data->ipython->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 1)) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\chris\documents\jupyter_server\venv\lib\site-packages (from stack_data->ipython->-r c:/Users/chris/Documents/jupyter_server/requirements-base.txt (line 1)) (0.2.3)
#  Optional installs mode: none
# Skipping all optional installs.
# --------------
# ✅ Script execution finished.

# %% [markdown]
# ## 🧭 Environment Monitoring and Version Verification
#
# This cell checks your local environment configuration to ensure compatibility and hardware readiness. It provides:
#
# - 🐍 **Python version** and executable path
# - 🧠 **Platform** and **CPU architecture**
# - 🔍 **PyTorch**: Installed status and CUDA GPU detection
# - 🧪 **TensorFlow**: Installed status and GPU device info
# - 🧾 **`watermark`**: Summarized snapshot of all package versions and machine metadata (if extension is available)
#
# > ℹ️ If a module is missing (e.g., `torch`, `tensorflow`, or `watermark`), the script will skip that section gracefully. No crashes.
#
# This step helps **validate installation success**, especially for optional GPU libraries. You can run this cell **at any time** to verify system status after changing packages or re-launching your environment.

# %%
# 📌 Environment Monitoring and Versions Display (Enhanced)
try:
    # %load_ext watermark
except:
    print("⚠️ 'watermark' is not installed. Skipping detailed environment printout.")

import sys
import platform

print("🔍 Python Environment Details")
print(f"✅ Python Version     : {platform.python_version()}")
print(f"✅ Platform           : {platform.platform()}")
print(f"✅ Processor          : {platform.processor()}")
import psutil

ram_bytes = psutil.virtual_memory().total
ram_gb = ram_bytes / (1024 ** 3)
print(f"✅ RAM                : {ram_gb:.2f} GB")
print(f"✅ Interpreter Path   : {sys.executable}")

print("\n🔧 Checking PyTorch GPU Support...")
try:
    import torch
    print(f"✅ PyTorch Installed  : Yes")
    print(f"✅ CUDA Available     : {torch.cuda.is_available()}")
    if torch.cuda.is_available():
        print(f"🖥️  GPU Name          : {torch.cuda.get_device_name(0)}")
except ImportError:
    print("ℹ️ PyTorch not installed.")

print("\n🔧 Checking TensorFlow GPU Support...")
try:
    import tensorflow as tf
    print(f"✅ TensorFlow Installed: Yes")
    gpu_devices = tf.config.list_physical_devices('GPU')
    if gpu_devices:
        for i, device in enumerate(gpu_devices):
            print(f"🖥️  GPU Device {i}       : {device.name}")
    else:
        print("❌ No GPU devices found.")
except ImportError:
    print("ℹ️ TensorFlow not installed.")

print("\n🧾 Executing watermark (if available)...")
try:
    # %watermark --iversions --python --cuda --machine --githash
except:
    print("ℹ️ 'watermark' output skipped (module missing or error).")

print("\n✅ Environment check complete.")
# Out:
# 🔍 Python Environment Details
# ✅ Python Version     : 3.11.8
# ✅ Platform           : macOS-15.3.2-arm64-arm-64bit
# ✅ Processor          : arm
# ✅ Interpreter Path   : /Users/holtharvey/Documents/GitHub/jupyter_server/venv/bin/python
#
# 🔧 Checking PyTorch GPU Support...
# ✅ PyTorch Installed  : Yes
# ✅ CUDA Available     : False
#
# 🔧 Checking TensorFlow GPU Support...
# ✅ TensorFlow Installed: Yes
# ❌ No GPU devices found.
#
# 🧾 Executing watermark (if available)...
# ℹ️ 'watermark' output skipped (module missing or error).
#
# ✅ Environment check complete.
